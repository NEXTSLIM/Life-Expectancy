# %% [markdown]
# # Life Expectancy Analisys

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
#from sklearn.preprocessing import Imputer
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ## Load the 3 data sets from Word Data Bank
# ***
# ### Country dataframe

# %%
country = pd.read_csv('data/Country.csv', index_col = None)
country.head(2)
# Out:
#   CountryCode                   Short Name                   Table Name  \
# 0         ABW                        Aruba                        Aruba
# 1         AFE  Africa Eastern and Southern  Africa Eastern and Southern
#
#                      Long Name 2-alpha code  Currency Unit  \
# 0                        Aruba           AW  Aruban florin
# 1  Africa Eastern and Southern           ZH            NaN
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
#
#                       Region  IncomeGroup WB-2 code  ...  \
# 0  Latin America & Caribbean  High income        AW  ...
# 1                        NaN          NaN        ZH  ...
#
#         System of trade  Government Accounting concept  \
# 0  General trade system                            NaN
# 1                   NaN                            NaN
#
#                      IMF data dissemination standard Latest population census  \
# 0  Enhanced General Data Dissemination System (e-...          2020 (expected)
# 1                                                NaN                      NaN
#
#   Latest household survey Source of most recent Income and expenditure data  \
# 0                     NaN                                               NaN
# 1                     NaN                                               NaN
#
#   Vital registration complete  Latest agricultural census  \
# 0                         Yes                         NaN
# 1                         NaN                         NaN
#
#   Latest industrial data Latest trade data
# 0                    NaN            2018.0
# 1                    NaN               NaN
#
# [2 rows x 30 columns]

# %%
country.shape
# Out:
# (265, 30)

# %% [markdown]
# The Country data frame has 31 descriptor columns for each of the 247 rows (countries of groups of countries). Let's get a sense for how many individual countries exist and how many aggregate groupings (e.g. world, regions, income groupings).

# %%
# ID aggregated rows by searching for 'aggregate' in the special notes column 
text = country.SpecialNotes.fillna('0')
len(text[text.str.contains('aggregate')])
# Out:
# 30

# %% [markdown]
# ### Load 'Series' dataframe (renamed as metrics)

# %%
metrics = pd.read_csv('data/Series.csv', index_col = None)

# %% [markdown]
# One row per series/metric, columns provide defintions, units, periodicity sources, etc. Now let's get a better sense for the key categories (and sub-categories) of development indicators.
#
# Interested in health/life expactancy as the target indicators. SP.DYN.LE00.IN is a good fit: Life expectancy at birth, total (years)

# %%
metrics[metrics.IndicatorName.str.contains('Life expectancy')].head()
# Out:
#             Series Code              Topic  \
# 1255  SP.DYN.LE00.FE.IN  Health: Mortality
# 1256     SP.DYN.LE00.IN  Health: Mortality
# 1257  SP.DYN.LE00.MA.IN  Health: Mortality
#
#                                  IndicatorName Short definition  \
# 1255  Life expectancy at birth, female (years)              NaN
# 1256   Life expectancy at birth, total (years)              NaN
# 1257    Life expectancy at birth, male (years)              NaN
#
#                                         Long definition Unit of measure  \
# 1255  Life expectancy at birth indicates the number ...             NaN
# 1256  Life expectancy at birth indicates the number ...             NaN
# 1257  Life expectancy at birth indicates the number ...             NaN
#
#      Periodicity Base Period Other notes Aggregation method  \
# 1255      Annual         NaN         NaN   Weighted average
# 1256      Annual         NaN         NaN   Weighted average
# 1257      Annual         NaN         NaN   Weighted average
#
#                              Limitations and exceptions  \
# 1255  Annual data series from United Nations Populat...
# 1256  Annual data series from United Nations Populat...
# 1257  Annual data series from United Nations Populat...
#
#      Notes from original source General comments  \
# 1255                        NaN              NaN
# 1256                        NaN              NaN
# 1257                        NaN              NaN
#
#                                                  Source  \
# 1255  (1) United Nations Population Division. World ...
# 1256  (1) United Nations Population Division. World ...
# 1257  (1) United Nations Population Division. World ...
#
#                     Statistical concept and methodology  \
# 1255  Life expectancy at birth used here is the aver...
# 1256  Life expectancy at birth used here is the aver...
# 1257  Life expectancy at birth used here is the aver...
#
#                                   Development relevance Related source links  \
# 1255  Mortality rates for different age groups (infa...                  NaN
# 1256  Mortality rates for different age groups (infa...                  NaN
# 1257  Mortality rates for different age groups (infa...                  NaN
#
#       Other web links Related indicators License Type
# 1255              NaN                NaN    CC BY-4.0
# 1256              NaN                NaN    CC BY-4.0
# 1257              NaN                NaN    CC BY-4.0

# %% [markdown]
# Briefly view all the indicator categories that are available as predictors of Life Expectancy

# %%
# Highlevel topic categories
splitTopics = metrics.Topic.str.partition(':')
splitTopics.groupby([0,2]).size()
# Out:
# 0                                           2
# Economic Policy & Debt                       Balance of payments: Capital & financial account                  11
#                                              Balance of payments: Current account: Balances                     4
#                                              Balance of payments: Current account: Goods, services & income    22
#                                              Balance of payments: Current account: Transfers                    7
#                                              Balance of payments: Reserves & other items                        6
#                                                                                                                ..
# Social Protection & Labor                    Labor force structure                                             28
#                                              Migration                                                          5
#                                              Performance                                                       27
#                                              Unemployment                                                      24
# World Bank, International Debt Statistics.                                                                      1
# Length: 90, dtype: int64

# %% [markdown]
# ### Load 'Indicators' dataframe (renamed as 'df')
# ***

# %%
df = pd.read_csv('data/indicators.csv', index_col=None)

#check availability of data and how missing values are handled (confirm unavailable data reported as'NaN')
df[df.IndicatorName.str.contains('GDP per capita')].groupby(['CountryName', 'IndicatorName']).size().unstack()
# Out:
# IndicatorName                GDP per capita (constant 2010 US$)  \
# CountryName
# Afghanistan                                                  61
# Africa Eastern and Southern                                  61
# Africa Western and Central                                   61
# Albania                                                      61
# Algeria                                                      61
# ...                                                         ...
# West Bank and Gaza                                           61
# World                                                        61
# Yemen, Rep.                                                  61
# Zambia                                                       61
# Zimbabwe                                                     61
#
# IndicatorName                GDP per capita (constant LCU)  \
# CountryName
# Afghanistan                                             61
# Africa Eastern and Southern                             61
# Africa Western and Central                              61
# Albania                                                 61
# Algeria                                                 61
# ...                                                    ...
# West Bank and Gaza                                      61
# World                                                   61
# Yemen, Rep.                                             61
# Zambia                                                  61
# Zimbabwe                                                61
#
# IndicatorName                GDP per capita (current LCU)  \
# CountryName
# Afghanistan                                            61
# Africa Eastern and Southern                            61
# Africa Western and Central                             61
# Albania                                                61
# Algeria                                                61
# ...                                                   ...
# West Bank and Gaza                                     61
# World                                                  61
# Yemen, Rep.                                            61
# Zambia                                                 61
# Zimbabwe                                               61
#
# IndicatorName                GDP per capita (current US$)  \
# CountryName
# Afghanistan                                            61
# Africa Eastern and Southern                            61
# Africa Western and Central                             61
# Albania                                                61
# Algeria                                                61
# ...                                                   ...
# West Bank and Gaza                                     61
# World                                                  61
# Yemen, Rep.                                            61
# Zambia                                                 61
# Zimbabwe                                               61
#
# IndicatorName                GDP per capita growth (annual %)  \
# CountryName
# Afghanistan                                                61
# Africa Eastern and Southern                                61
# Africa Western and Central                                 61
# Albania                                                    61
# Algeria                                                    61
# ...                                                       ...
# West Bank and Gaza                                         61
# World                                                      61
# Yemen, Rep.                                                61
# Zambia                                                     61
# Zimbabwe                                                   61
#
# IndicatorName                GDP per capita, PPP (constant 2017 international $)  \
# CountryName
# Afghanistan                                                                 61
# Africa Eastern and Southern                                                 61
# Africa Western and Central                                                  61
# Albania                                                                     61
# Algeria                                                                     61
# ...                                                                        ...
# West Bank and Gaza                                                          61
# World                                                                       61
# Yemen, Rep.                                                                 61
# Zambia                                                                      61
# Zimbabwe                                                                    61
#
# IndicatorName                GDP per capita, PPP (current international $)  \
# CountryName
# Afghanistan                                                             61
# Africa Eastern and Southern                                             61
# Africa Western and Central                                              61
# Albania                                                                 61
# Algeria                                                                 61
# ...                                                                    ...
# West Bank and Gaza                                                      61
# World                                                                   61
# Yemen, Rep.                                                             61
# Zambia                                                                  61
# Zimbabwe                                                                61
#
# IndicatorName                Government expenditure per student, primary (% of GDP per capita)  \
# CountryName
# Afghanistan                                                                 61
# Africa Eastern and Southern                                                 61
# Africa Western and Central                                                  61
# Albania                                                                     61
# Algeria                                                                     61
# ...                                                                        ...
# West Bank and Gaza                                                          61
# World                                                                       61
# Yemen, Rep.                                                                 61
# Zambia                                                                      61
# Zimbabwe                                                                    61
#
# IndicatorName                Government expenditure per student, secondary (% of GDP per capita)  \
# CountryName
# Afghanistan                                                                 61
# Africa Eastern and Southern                                                 61
# Africa Western and Central                                                  61
# Albania                                                                     61
# Algeria                                                                     61
# ...                                                                        ...
# West Bank and Gaza                                                          61
# World                                                                       61
# Yemen, Rep.                                                                 61
# Zambia                                                                      61
# Zimbabwe                                                                    61
#
# IndicatorName                Government expenditure per student, tertiary (% of GDP per capita)
# CountryName
# Afghanistan                                                                 61
# Africa Eastern and Southern                                                 61
# Africa Western and Central                                                  61
# Albania                                                                     61
# Algeria                                                                     61
# ...                                                                        ...
# West Bank and Gaza                                                          61
# World                                                                       61
# Yemen, Rep.                                                                 61
# Zambia                                                                      61
# Zimbabwe                                                                    61
#
# [266 rows x 10 columns]

# %% [markdown]
# ## Data wrangling & inferential statistics
# ***

# %% [markdown]
# ### Plot life expectancy trends for World Bank's country income groupings (high, med & low)

# %%
income = country[['CountryCode','IncomeGroup', 'SpecialNotes']]
df_Le = df.merge(income, left_on=df.CountryCode, right_on = income.CountryCode, how='outer')
df_Le = df_Le[(df_Le.IndicatorName =='Life expectancy at birth, total (years)') 
                              & (df_Le.SpecialNotes.str.contains('aggregate'))]

df_Le = pd.pivot_table(df_Le, values = 'Value', index='Year', columns='CountryName')

# %%
income_grps = ['World', 'High income', 'Upper middle income', 'Middle income','Lower middle income', 'Low income']

df_Le[income_grps].plot(figsize=(15,5))
plt.title('Life Expectancy by income level')
plt.ylabel('Life Expectancy (years)')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %%
# regions =  ['North America','Europe & Central Asia','East Asia & Pacific', 
#         'Latin America & Caribbean','Middle East & North Africa',
#         'South Asia','Sub-Saharan Africa']

regions = ['North America','European Union','Central Europe and the Baltics', 
        'Latin America & Caribbean (all income levels)','World',
        'East Asia & Pacific (all income levels)','Arab World',  
        'South Asia', 'Sub-Saharan Africa (all income levels)']

df_Le[regions].plot(figsize=(15,5))
plt.title('Life Expectancy, by Region')
plt.ylabel('Life Expectancy (years)')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-b5dc9748d236> in <module>
#       8         'South Asia', 'Sub-Saharan Africa (all income levels)']
#       9
# ---> 10 df_Le[regions].plot(figsize=(15,5))
#      11 plt.title('Life Expectancy, by Region')
#      12 plt.ylabel('Life Expectancy (years)')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['East Asia & Pacific (all income levels)', 'Latin America & Caribbean (all income levels)', 'Sub-Saharan Africa (all income levels)', 'South Asia'] not in index"

# %%
# Plot 2019 life expectancy for all countries, by income grouping
df_2019 = df.merge(income, left_on=df.CountryCode, right_on = income.CountryCode, how='outer')

df_2019 = df_2019[(df_2019.IndicatorName =='Life expectancy at birth, total (years)') & (df_2019.Year == 2019)]

sns.set_style("whitegrid")
plt.figure(figsize=(16, 6))
_ = sns.swarmplot(x='IncomeGroup', y = 'Value', data = df_2019)
_ = plt.xlabel('Income Group')
_ = plt.ylabel('Life Expectancy')
_ = plt.title('2019 Life expectancy by country income grouping')

plt.show()

# %%
df_2019.groupby(['IncomeGroup']).describe().unstack()[['Value']].round(1)
# Out:
#               IncomeGroup
# Value  count  High income            64.0
#               Low income             27.0
#               Lower middle income    55.0
#               Upper middle income    51.0
#        mean   High income            80.1
#               Low income             62.6
#               Lower middle income    68.8
#               Upper middle income    73.8
#        std    High income             3.0
#               Low income              4.9
#               Lower middle income     5.6
#               Upper middle income     4.3
#        min    High income            73.5
#               Low income             53.3
#               Lower middle income    54.3
#               Upper middle income    58.7
#        25%    High income            77.9
#               Low income             60.0
#               Lower middle income    64.7
#               Upper middle income    72.4
#        50%    High income            81.0
#               Low income             62.0
#               Lower middle income    69.9
#               Upper middle income    74.5
#        75%    High income            82.6
#               Low income             65.7
#               Lower middle income    72.8
#               Upper middle income    76.8
#        max    High income            85.1
#               Low income             72.7
#               Lower middle income    77.0
#               Upper middle income    80.3
# dtype: float64

# %% [markdown]
# ## Machine learning: Predicting life expectancy with linear regression
# *************
# First, let's set up the dataframe with the top ~20 features that could be used to predict life expectancy. These features were selected to present a well-populated and diverse representation of the available development indicators.

# %% [markdown]
# #### Setting up the dataframe, and EDA on the data subset

# %%
columns = {
            "SP.DYN.LE00.IN": "LifeExpectancy",
#             "SH.XPD.PCAP": "HealthSpend",
            'SP.ADO.TFRT': 'Adolescent_fertility',
            'NY.GDP.PCAP.CD': 'GDP',
#             'SH.STA.ACSN': 'Sanitation',
            'SP.RUR.TOTL.ZS': 'Rural_pop%',
            "NY.ADJ.AEDU.GN.ZS": "EduExp_percentGNI",
            'NY.ADJ.NNTY.KD.ZG': 'National_income_%growth',
#             'AG.LND.AGRI.ZS': 'Agricultural_land_%',
            'AG.LND.ARBL.ZS': 'Arable_land_%',
#             'MS.MIL.TOTL.TF.ZS': 'Armed_forces_%',
            'SL.EMP.1524.SP.ZS': 'Employment_ratio_15',
            'SE.PRM.ENRR': 'Primary_edu',
            'SE.PRM.ENRL': 'Secondary_edu',
            'SH.XPD.TOTL.ZS': 'Health_exp_%',
            'NE.IMP.GNFS.ZS': 'Imports_%GDP',
            'NV.IND.TOTL.ZS': 'Industry_%GDP',
            'IT.CEL.SETS.P2': 'Mobile_phones_per100',
#             'EN.POP.DNST': 'Population_density',
            'SM.POP.REFG': 'Refugee_population',
            'NE.TRD.GNFS.ZS': 'Trade_%GDP',
            'SL.UEM.TOTL.ZS': 'Unemployment_%'
#             'SH.MMR.RISK': 'Maternal_death_perc',
#             'SP.DYN.IMRT.IN': 'Mortality_infant _per1000',
#             'SH.DYN.NMRT': 'Mortality_neonatal_1000',
#             'SH.DYN.MORT': 'Mortality_sub5_1000'
          }

df.IndicatorCode = df.IndicatorCode.astype(str)
df.IndicatorName = df.IndicatorName.astype(str)

# Reshape the data so features are column headers, and countries are rows
pivot = df[df.Year==2019].pivot_table('Value','CountryName', 'IndicatorCode')

features = list(columns.keys())
df_features = pivot[features]
df_features.columns = df_features.columns.to_series()
flattened = pd.DataFrame(df_features.to_records())

df_ml = flattened.rename(index=str, columns=columns)

# Drop countries who do not have a life expectancy value 
df_ml = df_ml[pd.notnull(df_ml.LifeExpectancy)]
df_ml = df_ml.dropna(axis =0, how='any').drop('CountryName', axis = 1)

y = df_ml.LifeExpectancy.values.reshape(-1,1)
X = df_ml.drop(['LifeExpectancy'], axis = 1)

#View summary metrics of the features
X.describe().round(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-78-73ca5c605d20> in <module>
#      35
#      36 features = list(columns.keys())
# ---> 37 df_features = pivot[features]
#      38 df_features.columns = df_features.columns.to_series()
#      39 flattened = pd.DataFrame(df_features.to_records())
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: "['SH.XPD.PCAP', 'SH.STA.ACSN', 'MS.MIL.TOTL.TF.ZS', 'EN.POP.DNST', 'AG.LND.AGRI.ZS', 'AG.LND.ARBL.ZS', 'SH.XPD.TOTL.ZS'] not in index"

# %% [markdown]
# Visualize the correlation between all features by using the a heat maps and Pearson's correlation

# %%
df_ml.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-84364d0d9076> in <module>
# ----> 1 df_ml.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
#
# NameError: name 'df_ml' is not defined

# %% [markdown]
# Fit a linear regression model with all features, and view the coefficients.

# %%
lr = LinearRegression()
lr.fit(X, y)
y_pred = lr.predict(X)
lr.score(X, y)

pd.DataFrame({'features': X.columns, 'estimatedCoefficients': lr.coef_[0,:]})[['features', 'estimatedCoefficients']]
# Out:
#                    features  estimatedCoefficients
# 0               HealthSpend          -8.764092e-04
# 1      Adolescent_fertility          -1.644478e-02
# 2                       GDP           1.436123e-04
# 3                Sanitation           1.548599e-01
# 4                Rural_pop%          -1.010184e-01
# 5         EduExp_percentGNI          -6.068114e-01
# 6   National_income_%growth          -6.205710e-02
# 7       Agricultural_land_%          -3.155886e-02
# 8             Arable_land_%          -3.915116e-02
# 9            Armed_forces_%           1.782669e-01
# 10      Employment_ratio_15          -1.726726e-02
# 11              Primary_edu           2.926475e-02
# 12            Secondary_edu           1.142560e-08
# 13             Health_exp_%           2.092191e-01
# 14             Imports_%GDP          -1.308526e-02
# 15            Industry_%GDP          -1.092631e-01
# 16     Mobile_phones_per100          -8.718741e-03
# 17       Population_density           5.040263e-04
# 18       Refugee_population          -4.559723e-07
# 19               Trade_%GDP           1.508186e-02
# 20           Unemployment_%          -2.583920e-01

# %%
# Import regression modules
import statsmodels.api as sm
from statsmodels.formula.api import ols
model_ols = ols('y ~ X', df_ml).fit()
model_ols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.868
# Method:                 Least Squares   F-statistic:                     30.78
# Date:                Sun, 03 Dec 2017   Prob (F-statistic):           2.40e-28
# Time:                        11:39:06   Log-Likelihood:                -227.84
# No. Observations:                  96   AIC:                             499.7
# Df Residuals:                      74   BIC:                             556.1
# Df Model:                          21
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept     70.4854      6.609     10.665      0.000        57.317    83.654
# X[0]          -0.0009      0.001     -1.202      0.233        -0.002     0.001
# X[1]          -0.0164      0.019     -0.871      0.387        -0.054     0.021
# X[2]           0.0001   7.72e-05      1.859      0.067     -1.03e-05     0.000
# X[3]           0.1549      0.026      6.010      0.000         0.104     0.206
# X[4]          -0.1010      0.030     -3.362      0.001        -0.161    -0.041
# X[5]          -0.6068      0.264     -2.301      0.024        -1.132    -0.081
# X[6]          -0.0621      0.103     -0.605      0.547        -0.266     0.142
# X[7]          -0.0316      0.024     -1.332      0.187        -0.079     0.016
# X[8]          -0.0392      0.035     -1.132      0.261        -0.108     0.030
# X[9]           0.1783      0.586      0.304      0.762        -0.989     1.346
# X[10]         -0.0173      0.042     -0.414      0.680        -0.100     0.066
# X[11]          0.0293      0.034      0.864      0.390        -0.038     0.097
# X[12]       1.143e-08   1.15e-08      0.992      0.324     -1.15e-08  3.44e-08
# X[13]          0.2092      0.241      0.867      0.389        -0.272     0.690
# X[14]         -0.0131      0.082     -0.160      0.873        -0.176     0.150
# X[15]         -0.1093      0.066     -1.648      0.103        -0.241     0.023
# X[16]         -0.0087      0.017     -0.521      0.604        -0.042     0.025
# X[17]          0.0005      0.004      0.141      0.888        -0.007     0.008
# X[18]       -4.56e-07   4.77e-07     -0.956      0.342     -1.41e-06  4.95e-07
# X[19]          0.0151      0.044      0.345      0.731        -0.072     0.102
# X[20]         -0.2584      0.086     -3.000      0.004        -0.430    -0.087
# ==============================================================================
# Omnibus:                        2.713   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.258   Jarque-Bera (JB):                2.456
# Skew:                          -0.096   Prob(JB):                        0.293
# Kurtosis:                       3.759   Cond. No.                     2.78e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.78e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Fit a regression based on top features (selected based on high correlation & low P)

# %%
X_top = df_ml.loc[:,('Sanitation', 'Rural_pop%')]
# X_top = df_ml.loc[:,('Sanitation', 'Rural_pop%', 'HealthSpend')]

X_train, X_test, y_train, y_test = train_test_split(X_top, y, test_size = 0.3, random_state=42) 
lr = LinearRegression()

lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
lr.score(X_test, y_test)

import numpy as np 
cv_results = cross_val_score(lr, X_top, y, cv = 5)
print('Model accuracy with 5 cross validation folds: {}' .format(np.mean(cv_results)))
# Out:
# Model accuracy with 5 cross validation folds: 0.8040573833835737

# %%
# The coefficients
pd.DataFrame({'features': X_top.columns, 'estimatedCoefficients': lr.coef_[0,:]})[['features', 'estimatedCoefficients']]
# Out:
#      features  estimatedCoefficients
# 0  Sanitation               0.183838
# 1  Rural_pop%              -0.117126

# %%
lr.intercept_
# Out:
# array([ 62.8683215])

# %%
# scatter plot between actual and predicted life expectancy
y_predicted = lr.predict(X_top)
plt.figure(figsize=(10,6))
plt.scatter(y_predicted, y)
plt.xlabel("Predicted")
plt.ylabel("Actual life span")
plt.title('Evaluation of model-predicted life expectancy')

# %% [markdown]
# If we look just at Sanitation (below), we see that the Regression coefficient is 0.2485, meaning on average each 0.25% increase in the percent of the population with access to modern sanitation facilities, is associated with a one-year increase in life expectancy.

# %%
X_sani = df_ml.loc[:,('Sanitation')].values.reshape(-1,1)
X_top = df_ml.loc[:,('Sanitation', 'Rural_pop%')]

X_train, X_test, y_train, y_test = train_test_split(X_sani, y, test_size = 0.3, random_state=42) 
lr = LinearRegression()

lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
lr.score(X_test, y_test)
 
cv_results = cross_val_score(lr, X_sani, y, cv = 5)
print('Model accuracy with 10 cross validation folds: {}' .format(np.mean(cv_results)))
# Out:
# Model accuracy with 10 cross validation folds: 0.770179159601213

# %%
lr.coef_
# Out:
# array([[ 0.24664406]])

# %% [markdown]
# # Access to sanitation is the biggest drive for life expectancy
# Let's dig into the age groups most affected by poor sanitation. We have Mortality rates for neonatals, infants and children under 5, as well as the maternal death rate. Repeating the steps above, we'll create a sub-set of the dataframe with the relevant columns, then run a correlation across this sub-set.

# %%
# Create a sub-set of columns 
columns_san = {
            'SH.STA.ACSN': 'Sanitation_perc_access',
            "SP.DYN.LE00.IN": "LifeExpect_total",
            'SH.MMR.RISK': 'Maternal_death_perc',
            'SP.DYN.IMRT.IN': 'Mortality_infant _per1000',
            'SH.DYN.NMRT': 'Mortality_neonatal_1000',
            'SH.DYN.MORT': 'Mortality_sub5_1000',
          }

df.IndicatorCode = df.IndicatorCode.astype(str)
df.IndicatorName = df.IndicatorName.astype(str)

# piovt the 2013 data so the features are column headers
pivot_san = df[df.Year==2013].pivot_table('Value','CountryName', 'IndicatorCode')

features = list(columns_san.keys())
df_features = pivot[features]
df_features.columns = df_features.columns.to_series()
flattened = pd.DataFrame(df_features.to_records())

df_ml = flattened.rename(index=str, columns=columns_san)

# Drop countries who do not have a life expectancy value 
df_ml = df_ml[pd.notnull(df_ml.LifeExpect_total)]
df_ml = df_ml.dropna(axis =0, how='any').drop('CountryName', axis = 1)

# %%
df_ml.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
#         <style  type="text/css" >
#
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow0_col0 {
#
#                 background-color:  #b40426;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow0_col1 {
#
#                 background-color:  #cf453c;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow0_col2 {
#
#                 background-color:  #f59c7d;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow0_col3 {
#
#                 background-color:  #3b4cc0;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow0_col4 {
#
#                 background-color:  #3e51c5;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow0_col5 {
#
#                 background-color:  #3b4cc0;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow1_col0 {
#
#                 background-color:  #cd423b;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow1_col1 {
#
#                 background-color:  #b40426;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow1_col2 {
#
#                 background-color:  #ef886b;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow1_col3 {
#
#                 background-color:  #3b4cc0;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow1_col4 {
#
#                 background-color:  #4055c8;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow1_col5 {
#
#                 background-color:  #3b4cc0;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow2_col0 {
#
#                 background-color:  #f7aa8c;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow2_col1 {
#
#                 background-color:  #f49a7b;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow2_col2 {
#
#                 background-color:  #b40426;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow2_col3 {
#
#                 background-color:  #4055c8;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow2_col4 {
#
#                 background-color:  #3b4cc0;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow2_col5 {
#
#                 background-color:  #485fd1;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow3_col0 {
#
#                 background-color:  #465ecf;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow3_col1 {
#
#                 background-color:  #3b4cc0;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow3_col2 {
#
#                 background-color:  #799cf8;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow3_col3 {
#
#                 background-color:  #b40426;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow3_col4 {
#
#                 background-color:  #ba162b;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow3_col5 {
#
#                 background-color:  #b50927;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow4_col0 {
#
#                 background-color:  #4358cb;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow4_col1 {
#
#                 background-color:  #3b4cc0;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow4_col2 {
#
#                 background-color:  #6c8ff1;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow4_col3 {
#
#                 background-color:  #ba162b;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow4_col4 {
#
#                 background-color:  #b40426;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow4_col5 {
#
#                 background-color:  #bd1f2d;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow5_col0 {
#
#                 background-color:  #455cce;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow5_col1 {
#
#                 background-color:  #3b4cc0;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow5_col2 {
#
#                 background-color:  #80a3fa;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow5_col3 {
#
#                 background-color:  #b50927;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow5_col4 {
#
#                 background-color:  #bd1f2d;
#
#             }
#
#             #T_49d152d4_d860_11e7_9af9_80e65000067arow5_col5 {
#
#                 background-color:  #b40426;
#
#             }
#
#         </style>
#
#         <table id="T_49d152d4_d860_11e7_9af9_80e65000067a" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   Sanitation_perc_access
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   LifeExpect_total
#
#
#
#                 <th class="col_heading level0 col2" colspan=1>
#                   Maternal_death_perc
#
#
#
#                 <th class="col_heading level0 col3" colspan=1>
#                   Mortality_infant _per1000
#
#
#
#                 <th class="col_heading level0 col4" colspan=1>
#                   Mortality_neonatal_1000
#
#
#
#                 <th class="col_heading level0 col5" colspan=1>
#                   Mortality_sub5_1000
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_49d152d4_d860_11e7_9af9_80e65000067a"
#                  class="row_heading level0 row0" rowspan=1>
#                     Sanitation_perc_access
#
#
#
#                 <td id="T_49d152d4_d860_11e7_9af9_80e65000067arow0_col0"
#                  class="data row0 col0" >
#                     1.0
#
#
#
#                 <td id="T_49d152d4_d860_11e7_9af9_80e65000067arow0_col1"
#                  class="data row0 col1" >
#                     0.86
#
#
#
#                 <td id="T_49d152d4_d860_11e7_9af9_80e65000067arow0_col2"
#                  class="data row0 col2" >
#                     0.53
#
#
#
#                 <td id="T_49d152d4_d860_11e7_9af9_80e65000067arow0_col3"
#                  class="data row0 col3" >
#                     -0.85
#
#
#
#                 <td id="T_49d1
